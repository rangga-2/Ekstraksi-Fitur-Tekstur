# %% [markdown]
# <a href="https://colab.research.google.com/github/rangga-2/Ekstraksi-Fitur-Tekstur/blob/main/2318100RanggaEkstraksiFiturTekstur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Mount Google Drive**

# %%
#Untuk mengkoneksikan Google Colab dengan Folder Google Drive
from google.colab import drive
#Untuk memulai proses mounting dari google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **2. Load Data 10 File Citra yang ada pada File Google Drive**

# %%
#Melakukan import library os untuk membuat dan menghapus direktori, mengambil isi direktori, dll
import os

#Mendefinisikan variabel untuk menyimpan lokasi folder citra di dalam Google Drive
folder_path = '/content/drive/MyDrive/Colab Notebooks/Dataset Perkotaan'

#Untuk mengubah direktori sesuai dengan nilai variabel folder_path
os.chdir(folder_path)

#Melakukan perulangan dengan kondisi akhir sesuai jumlah isi file di dalam folder
for file_name in os.listdir(folder_path):
    #Mencetak pesan nama file yang ada di dalam folder
    print(f"Nama File: {file_name}")
# Out:
# Nama File: Gambar 2.jpg
# Nama File: Gambar 1.jpg
# Nama File: Gambar 5.jpg
# Nama File: Gambar 9.jpg
# Nama File: Gambar 4.jpg
# Nama File: Gambar 3.jpg
# Nama File: Gambar 8.jpg
# Nama File: Gambar 7.jpg
# Nama File: Gambar 10.jpg
# Nama File: Gambar 6.jpg
# Nama File: 2318100_HasilEkstraksiFitur.xlsx

# %% [markdown]
# **3. Melakukan Konversi Citra RGB ke Grayscale**

# %%
#Melakukan import library opencv yang digunakan untuk melakukan konversi color space
import cv2

#Mendefinisikan variabel untuk menyimpan lokasi folder citra di dalam Google Drive
folder_path = '/content/drive/MyDrive/Colab Notebooks/Dataset Perkotaan'

#Melakukan perulangan dengan kondisi akhir sesuai jumlah isi file di dalam folder
for file_name in os.listdir(folder_path):
    #Menentukan spesifikasi file citra yang akan digunakan, yaitu yang memiliki ekstensi.jpg, .jpeg, dan .png
    if file_name.endswith('.jpg') or file_name.endswith('.jpeg') or file_name.endswith('.png'):
        #Membaca file citra yang ada di dalam folder Google Drive
        image = cv2.imread(os.path.join(folder_path, file_name))
        #Melakukan konversi citra dari BGR menjadi Grayscale
        grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        #Menyimpan dan mendefinisikan nama file citra hasil konversi ke dalam folder Google Drive
        cv2.imwrite(os.path.join(folder_path, f"grayscale_{file_name}"), grayscale_image)
        #Mencetak pesan berhasil mengkonversi citra
        print(f'File {file_name} berhasil diubah menjadi grayscale.')
# Out:
# File Gambar 2.jpg berhasil diubah menjadi grayscale.
# File Gambar 1.jpg berhasil diubah menjadi grayscale.
# File Gambar 5.jpg berhasil diubah menjadi grayscale.
# File Gambar 9.jpg berhasil diubah menjadi grayscale.
# File Gambar 4.jpg berhasil diubah menjadi grayscale.
# File Gambar 3.jpg berhasil diubah menjadi grayscale.
# File Gambar 8.jpg berhasil diubah menjadi grayscale.
# File Gambar 7.jpg berhasil diubah menjadi grayscale.
# File Gambar 10.jpg berhasil diubah menjadi grayscale.
# File Gambar 6.jpg berhasil diubah menjadi grayscale.

# %% [markdown]
# **4. Melakukan Ekstraksi Fitur Tekstur pada 10 Citra**

# %%
#Melakukan import library os untuk membuat dan menghapus direktori, mengambil isi direktori, dll
import os
#Melakukan import library opencv yang digunakan untuk melakukan konversi color space
import cv2
#Melakukan import library NumPy yang digunakan untuk membentuk objek N-dimensional array
import numpy as np
#Melakukan import graycomatrix untuk menghitung matriks co-occurance tingkat keabuan, dan graycoprops untuk menghitung properti tekstur dari GLCM dari library skimage.feature
from skimage.feature import graycomatrix, graycoprops
#Melakukan import library Pandas yang digunakan untuk membaca isi file excel
import pandas as pd

#Mendefinisikan variabel untuk menyimpan lokasi folder citra di dalam Google Drive
folder_path = '/content/drive/MyDrive/Colab Notebooks/Dataset Perkotaan'
#Membuat variabel array kosong yang akan digunakan untuk menampung nilai fitur hasil ekstraksi
nilai_fitur = []

#Melakukan perulangan dengan kondisi akhir sesuai jumlah isi file di dalam folder
for file_name in os.listdir(folder_path):
    #Menentukan spesifikasi file citra yang akan digunakan, yaitu yang memiliki ekstensi.jpg, .jpeg, dan .png
    if file_name.endswith(".jpg") or file_name.endswith('.jpeg') or file_name.endswith(".png"):
        #Membaca file citra yang ada di dalam folder Google Drive
        image = cv2.imread(os.path.join(folder_path, file_name))
        #Melakukan konversi citra dari BGR menjadi Grayscale
        grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        #Menghitung matriks co-occurance dari citra hasil konversi
        glcm = graycomatrix(grayscale_image, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4], symmetric=True, normed=True)
        #Menghitung rata-rata properti tekstur energi dari GLCM
        energi = graycoprops(glcm, 'energy').mean()
        #Menghitung rata-rata properti tekstur kontras dari GLCM
        kontras = graycoprops(glcm, 'contrast').mean()
        #Menghitung rata-rata properti tekstur korelasi dari GLCM
        korelasi = graycoprops(glcm, 'correlation').mean()
        #Menghitung rata-rata properti tekstur homogenitas dari GLCM
        homogenitas = graycoprops(glcm, 'homogeneity').mean()
        #Menampung nilai fitur ke dalam variabel array nilai_fitur
        nilai_fitur.append([file_name, energi, kontras, korelasi, homogenitas])

        #Mencetak nama file
        print(f"File {file_name}:")
        #Mencetak nilai energi
        print(f"Energi: {energi:.3f}")
        #Mencetak nilai kontras
        print(f"Kontras: {kontras:.3f}")
        #Mencetak nilai korelasi
        print(f"Korelasi: {korelasi:.3f}")
        #Mencetak nilai homogenitas
        print(f"Homogenitas: {homogenitas:.3f}")
    else:
        #Mencetak nama file jika bukan gambar
        print(f"Nama File: {file_name}")
# Out:
# File Gambar 2.jpg:
# Energi: 0.013
# Kontras: 287.364
# Korelasi: 0.933
# Homogenitas: 0.130
# File Gambar 1.jpg:
# Energi: 0.014
# Kontras: 699.635
# Korelasi: 0.894
# Homogenitas: 0.175
# File Gambar 5.jpg:
# Energi: 0.015
# Kontras: 284.359
# Korelasi: 0.944
# Homogenitas: 0.136
# File Gambar 9.jpg:
# Energi: 0.014
# Kontras: 251.939
# Korelasi: 0.940
# Homogenitas: 0.148
# File Gambar 4.jpg:
# Energi: 0.013
# Kontras: 308.905
# Korelasi: 0.944
# Homogenitas: 0.137
# File Gambar 3.jpg:
# Energi: 0.015
# Kontras: 259.717
# Korelasi: 0.933
# Homogenitas: 0.148
# File Gambar 8.jpg:
# Energi: 0.014
# Kontras: 450.403
# Korelasi: 0.932
# Homogenitas: 0.160
# File Gambar 7.jpg:
# Energi: 0.012
# Kontras: 547.259
# Korelasi: 0.917
# Homogenitas: 0.136
# File Gambar 10.jpg:
# Energi: 0.011
# Kontras: 479.039
# Korelasi: 0.923
# Homogenitas: 0.139
# File Gambar 6.jpg:
# Energi: 0.014
# Kontras: 324.204
# Korelasi: 0.932
# Homogenitas: 0.151
# Nama File: 2318100_HasilEkstraksiFitur.xlsx
# File grayscale_Gambar 2.jpg:
# Energi: 0.013
# Kontras: 287.495
# Korelasi: 0.933
# Homogenitas: 0.130
# File grayscale_Gambar 1.jpg:
# Energi: 0.014
# Kontras: 699.991
# Korelasi: 0.894
# Homogenitas: 0.175
# File grayscale_Gambar 5.jpg:
# Energi: 0.014
# Kontras: 284.577
# Korelasi: 0.944
# Homogenitas: 0.135
# File grayscale_Gambar 9.jpg:
# Energi: 0.014
# Kontras: 252.094
# Korelasi: 0.940
# Homogenitas: 0.147
# File grayscale_Gambar 4.jpg:
# Energi: 0.013
# Kontras: 309.139
# Korelasi: 0.944
# Homogenitas: 0.136
# File grayscale_Gambar 3.jpg:
# Energi: 0.015
# Kontras: 259.847
# Korelasi: 0.933
# Homogenitas: 0.148
# File grayscale_Gambar 8.jpg:
# Energi: 0.014
# Kontras: 450.517
# Korelasi: 0.932
# Homogenitas: 0.160
# File grayscale_Gambar 7.jpg:
# Energi: 0.012
# Kontras: 547.401
# Korelasi: 0.917
# Homogenitas: 0.136
# File grayscale_Gambar 10.jpg:
# Energi: 0.011
# Kontras: 479.135
# Korelasi: 0.923
# Homogenitas: 0.139
# File grayscale_Gambar 6.jpg:
# Energi: 0.014
# Kontras: 324.251
# Korelasi: 0.932
# Homogenitas: 0.151

# %% [markdown]
# **5. Melakukan Penampungan Nilai-Nilai Fitur ke dalam File .xlsx dan Membuka isi File .xlsx**

# %%
#Mendefinisikan variabel untuk menyimpan nama kolom pada excel
nama_kolom = ['Nama File', 'Energi', 'Kontras', 'Korelasi', 'Homogenitas']
#Menyimpan nilai-nilai hasil ekstraksi fitur ke dalam dataframe
fitur_dataframe = pd.DataFrame(nilai_fitur, columns=nama_kolom)

#Mendefinisikan variabel untuk menyimpan nama dan ekstensi file
nama_file = '2318100_HasilEkstraksiFitur.xlsx'
#Menyimpan dataframe ke dalam file excel dengan nama sesuai dengan variabel nama_file
fitur_dataframe.to_excel(nama_file, index=False)

#Mencetak pesan bahwa file berhasil disimpan
print(f'File {nama_file} Berhasil Disimpan.')

#Membaca file excel yang sudah dibuat
excel = pd.read_excel('2318100_HasilEkstraksiFitur.xlsx')

#Mencetak isi dari file excel
print(excel)
# Out:
# File 2318100_HasilEkstraksiFitur.xlsx Berhasil Disimpan.
#                   Nama File    Energi     Kontras  Korelasi  Homogenitas
# 0              Gambar 2.jpg  0.012845  287.364169  0.932843     0.130369
# 1              Gambar 1.jpg  0.014145  699.635204  0.894020     0.175419
# 2              Gambar 5.jpg  0.014527  284.358502  0.944342     0.135518
# 3              Gambar 9.jpg  0.013578  251.938543  0.939836     0.147685
# 4              Gambar 4.jpg  0.013422  308.905253  0.943803     0.136706
# 5              Gambar 3.jpg  0.014981  259.717302  0.933308     0.148484
# 6              Gambar 8.jpg  0.014425  450.402520  0.931562     0.160493
# 7              Gambar 7.jpg  0.012315  547.258708  0.917347     0.136087
# 8             Gambar 10.jpg  0.011276  479.039084  0.923089     0.139316
# 9              Gambar 6.jpg  0.013785  324.203519  0.931668     0.150785
# 10   grayscale_Gambar 2.jpg  0.012826  287.494932  0.932825     0.130017
# 11   grayscale_Gambar 1.jpg  0.014144  699.990826  0.893991     0.175198
# 12   grayscale_Gambar 5.jpg  0.014462  284.576587  0.944317     0.134680
# 13   grayscale_Gambar 9.jpg  0.013563  252.094170  0.939812     0.147278
# 14   grayscale_Gambar 4.jpg  0.013377  309.139049  0.943776     0.136074
# 15   grayscale_Gambar 3.jpg  0.014951  259.847257  0.933288     0.147936
# 16   grayscale_Gambar 8.jpg  0.014421  450.516538  0.931552     0.160313
# 17   grayscale_Gambar 7.jpg  0.012310  547.401314  0.917336     0.135872
# 18  grayscale_Gambar 10.jpg  0.011273  479.134704  0.923081     0.139174
# 19   grayscale_Gambar 6.jpg  0.013785  324.250857  0.931663     0.150697
